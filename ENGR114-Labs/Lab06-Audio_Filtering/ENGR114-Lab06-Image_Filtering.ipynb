# %% [markdown]
# # Lab 06 - Image Filtering

# %% [markdown]
# ## Prelab
#
# Before starting the lab, read through this entire document. Then review how Matplotlib can be used to display images. The Matplotlib documentaiton on showing images with ```plt.imshow()``` is found here: [https://matplotlib.org/api/_as_gen/matplotlib.pyplot.imshow.html](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.imshow.html). Also be familiar with Python's ```input()``` function and ```if``` / ```elif``` / ```else``` selection structures.

# %% [markdown]
# ## Lab
#
# In this lab assignment, your group will show a user an image and soliciate input from the user regarding how to modify the image. Based on the user's input, you will re-display the image with modifications.
#
# The image below is the image the user will modify:
#
# ![stinkbug](stinkbug.png)
#
# The image can be found online here: [https://matplotlib.org/users/image_tutorial.html](https://matplotlib.org/users/image_tutorial.html)
#
# Images can be displayed using Python and Matplotlib. The code cell below demonstrates how to read and display an image with Matplotlib. Ensure that the image you want to show is in the same directory as your Jupyter notebook.

# %%
import numpy as np
import matplotlib.pyplot as plt

image = plt.imread('stinkbug.png')

fig, ax = plt.subplots()
ax.imshow(image)

plt.show()

# %% [markdown]
# The ```stinkbug.png``` image is a gray scale image, but Matplotlib is rendering it as a color image. We can include an extra argument in the ```ax.imshow()``` method to choose a different color map. A list of all the possible color maps can be found on the Matplotlib documentation ([https://matplotlib.org/examples/color/colormaps_reference.html](https://matplotlib.org/examples/color/colormaps_reference.html)).
#
# The code cell below demonstartes how to use a custom color map to display the image

# %%
import numpy as np
import matplotlib.pyplot as plt

image = plt.imread('stinkbug.png')

fig, ax = plt.subplots(figsize=(9,9))
ax.imshow(image, cmap='Greys')

plt.show()

# %% [markdown]
# Construct a script that tells a user different colormaps they can select from. Then use Python's ```input()``` function to ask the user for a color map. Then ask the user if they want gridlines. Finally ask the user if they want tick labels. After the user selects all of the options, show the user the image based on their preferences.
#
# The code below demonstrates how the script might function:
#
# ```text
# Possible color maps are: Greys, gist_earth, ocean and terrain
#
# Select a color map:
# terrain
#
# Do you want grid lines? (yes or no):
# yes
#
# Do you want tick labels? (yes or no):
# no
# ```
#
# ![Image terrain colormap, no gridlines, no tick labels](images/image1.png)

# %% [markdown]
# ## Deliverables
#
# Each student’s submission for the lab should be one Jupyter notebook .ipynb-file. Upload to the appropriate D2L drop box.
#
# **lab6.ipynb**

# %% [markdown]
# #### _By P. Kazarinoff, Portland Community College, 2019_
